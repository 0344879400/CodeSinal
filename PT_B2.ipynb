# %%
import math
#ax^2 + bx +c =0
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
delta = b*b - (a*4*c)

def checkpt(a,b,c):
    
    if (a == 0):
        
        print("this is not PT_B2")
    else:
        if delta < 0:
            print("delta = ",delta)
            print("->PT_Vo nghiem")
        elif delta == 0:
            print("PT_co 2 nghiem kep la: x1 = x2 = ",-b/(2*a))
        else:
            x1 = (-b + math.sqrt(delta))/ (2*a)
            x2 = (-b - math.sqrt(delta))/ (2*a)
            print("X1 = ",x1," x2 = ",x2)
            
checkpt(a,b,c)
# Out:
# a = 1
# b = 3
# c = 1
# X1 =  -0.3819660112501051  x2 =  -2.618033988749895
